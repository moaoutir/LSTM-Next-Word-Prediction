# %%
from PyPDF2 import PdfReader
import re
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,LSTM,Dense,Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import load_model
import pickle
import os

# %%
file_path = "./antigone.pdf"

# %%
reader = PdfReader(file_path)
start_page = 6
text = ""

for page in reader.pages[start_page:]:
    text += re.sub(r"[0-9\n()]", '', page.extract_text())

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])
total_words = len(tokenizer.word_index) + 1

# %%
input_sequences=[]
for line in text.split('.'):
  if line.strip() != '':
    token_list=tokenizer.texts_to_sequences([line])[0]
    for i in range(1,len(token_list)):
        n_gram_sequence=token_list[:i+1]
        input_sequences.append(n_gram_sequence)

# %%
## Pad Sequences
max_sequence_len=max([len(x) for x in input_sequences])
max_sequence_len
# Out:
# 115

# %%
input_sequences=np.array(pad_sequences(input_sequences,maxlen=max_sequence_len,padding='pre'))

# %%
X,y = input_sequences[:,:-1],input_sequences[:,-1]

# %%
y = np.array(tf.keras.utils.to_categorical(y, num_classes=total_words))

# %%
model = Sequential()
model.add(Embedding(total_words, 100))
model.add(LSTM(150))
model.add(Dense(total_words, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
early_stopping=EarlyStopping(
    monitor="loss",
    patience=20,
    verbose=0,
    restore_best_weights=True,
)
model.fit(X, y,
          epochs=100,
          validation_split=0.2,
          verbose=1,
          batch_size=64,
          callbacks=[early_stopping])

## Save the model
model.save("model.keras")
## Save the tokenizer
with open('/tokenizer.pickle','wb') as handle:
    pickle.dump(tokenizer,handle,protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Epoch 1/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 43s 205ms/step - accuracy: 0.0186 - loss: 7.0359 - val_accuracy: 0.0135 - val_loss: 6.6756
# Epoch 2/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 37s 188ms/step - accuracy: 0.0232 - loss: 6.2267 - val_accuracy: 0.0340 - val_loss: 6.7743
# Epoch 3/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 37s 190ms/step - accuracy: 0.0361 - loss: 6.1367 - val_accuracy: 0.0408 - val_loss: 6.8653
# Epoch 4/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 34s 172ms/step - accuracy: 0.0467 - loss: 5.9718 - val_accuracy: 0.0459 - val_loss: 6.8693
# Epoch 5/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 34s 174ms/step - accuracy: 0.0549 - loss: 5.8166 - val_accuracy: 0.0526 - val_loss: 6.8499
# Epoch 6/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 37s 190ms/step - accuracy: 0.0669 - loss: 5.6553 - val_accuracy: 0.0639 - val_loss: 6.8506
# Epoch 7/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 35s 180ms/step - accuracy: 0.0757 - loss: 5.4952 - val_accuracy: 0.0632 - val_loss: 6.8364
# Epoch 8/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 32s 162ms/step - accuracy: 0.0827 - loss: 5.3188 - val_accuracy: 0.0777 - val_loss: 6.8262
# Epoch 9/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 32s 164ms/step - accuracy: 0.1010 - loss: 5.1310 - val_accuracy: 0.0790 - val_loss: 6.8543
# Epoch 10/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 32s 164ms/step - accuracy: 0.1130 - loss: 4.9814 - val_accuracy: 0.0803 - val_loss: 6.8758
# Epoch 11/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 34s 174ms/step - accuracy: 0.1159 - loss: 4.8380 - val_accuracy: 0.0838 - val_loss: 6.9144
# Epoch 12/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 33s 171ms/step - accuracy: 0.1353 - loss: 4.6979 - val_accuracy: 0.0819 - val_loss: 6.9413
# Epoch 13/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 34s 172ms/step - accuracy: 0.1391 - loss: 4.5851 - val_accuracy: 0.0867 - val_loss: 6.9927
# Epoch 14/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 157ms/step - accuracy: 0.1601 - loss: 4.4193 - val_accuracy: 0.0825 - val_loss: 7.0259
# Epoch 15/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 29s 151ms/step - accuracy: 0.1732 - loss: 4.2699 - val_accuracy: 0.0825 - val_loss: 7.0689
# Epoch 16/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 29s 150ms/step - accuracy: 0.1791 - loss: 4.1516 - val_accuracy: 0.0883 - val_loss: 7.0960
# Epoch 17/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 156ms/step - accuracy: 0.1968 - loss: 4.0022 - val_accuracy: 0.0851 - val_loss: 7.1576
# Epoch 18/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 154ms/step - accuracy: 0.2127 - loss: 3.8544 - val_accuracy: 0.0889 - val_loss: 7.2103
# Epoch 19/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 154ms/step - accuracy: 0.2241 - loss: 3.7436 - val_accuracy: 0.0899 - val_loss: 7.2479
# Epoch 20/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 155ms/step - accuracy: 0.2400 - loss: 3.6513 - val_accuracy: 0.0835 - val_loss: 7.2914
# Epoch 21/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 154ms/step - accuracy: 0.2550 - loss: 3.5147 - val_accuracy: 0.0896 - val_loss: 7.3338
# Epoch 22/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 153ms/step - accuracy: 0.2810 - loss: 3.3743 - val_accuracy: 0.0857 - val_loss: 7.3875
# Epoch 23/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 153ms/step - accuracy: 0.2954 - loss: 3.2830 - val_accuracy: 0.0848 - val_loss: 7.4466
# Epoch 24/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 155ms/step - accuracy: 0.3213 - loss: 3.1688 - val_accuracy: 0.0912 - val_loss: 7.4972
# Epoch 25/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 153ms/step - accuracy: 0.3332 - loss: 3.0643 - val_accuracy: 0.0860 - val_loss: 7.5555
# Epoch 26/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 158ms/step - accuracy: 0.3643 - loss: 2.9494 - val_accuracy: 0.0899 - val_loss: 7.6178
# Epoch 27/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 154ms/step - accuracy: 0.3770 - loss: 2.8399 - val_accuracy: 0.0819 - val_loss: 7.6810
# Epoch 28/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 155ms/step - accuracy: 0.3999 - loss: 2.7530 - val_accuracy: 0.0835 - val_loss: 7.7329
# Epoch 29/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 159ms/step - accuracy: 0.4128 - loss: 2.6464 - val_accuracy: 0.0780 - val_loss: 7.7955
# Epoch 30/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 156ms/step - accuracy: 0.4372 - loss: 2.5756 - val_accuracy: 0.0819 - val_loss: 7.8351
# Epoch 31/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 155ms/step - accuracy: 0.4520 - loss: 2.4856 - val_accuracy: 0.0828 - val_loss: 7.8979
# Epoch 32/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 156ms/step - accuracy: 0.4815 - loss: 2.3821 - val_accuracy: 0.0806 - val_loss: 7.9580
# Epoch 33/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 157ms/step - accuracy: 0.4892 - loss: 2.3005 - val_accuracy: 0.0835 - val_loss: 8.0249
# Epoch 34/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 158ms/step - accuracy: 0.5033 - loss: 2.2366 - val_accuracy: 0.0803 - val_loss: 8.0674
# Epoch 35/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 159ms/step - accuracy: 0.5245 - loss: 2.1531 - val_accuracy: 0.0803 - val_loss: 8.1276
# Epoch 36/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 156ms/step - accuracy: 0.5424 - loss: 2.1071 - val_accuracy: 0.0796 - val_loss: 8.1943
# Epoch 37/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 155ms/step - accuracy: 0.5558 - loss: 2.0104 - val_accuracy: 0.0787 - val_loss: 8.2559
# Epoch 38/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 156ms/step - accuracy: 0.5584 - loss: 1.9888 - val_accuracy: 0.0758 - val_loss: 8.3093
# Epoch 39/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 156ms/step - accuracy: 0.5819 - loss: 1.9117 - val_accuracy: 0.0767 - val_loss: 8.3661
# Epoch 40/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 157ms/step - accuracy: 0.5947 - loss: 1.8624 - val_accuracy: 0.0793 - val_loss: 8.4381
# Epoch 41/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 155ms/step - accuracy: 0.6005 - loss: 1.8047 - val_accuracy: 0.0777 - val_loss: 8.4880
# Epoch 42/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 156ms/step - accuracy: 0.6140 - loss: 1.7554 - val_accuracy: 0.0777 - val_loss: 8.5646
# Epoch 43/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 156ms/step - accuracy: 0.6306 - loss: 1.6893 - val_accuracy: 0.0777 - val_loss: 8.6190
# Epoch 44/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 157ms/step - accuracy: 0.6450 - loss: 1.6449 - val_accuracy: 0.0774 - val_loss: 8.6787
# Epoch 45/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 157ms/step - accuracy: 0.6436 - loss: 1.6147 - val_accuracy: 0.0793 - val_loss: 8.7412
# Epoch 46/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 157ms/step - accuracy: 0.6607 - loss: 1.5606 - val_accuracy: 0.0767 - val_loss: 8.8098
# Epoch 47/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 157ms/step - accuracy: 0.6744 - loss: 1.5026 - val_accuracy: 0.0761 - val_loss: 8.8745
# Epoch 48/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 158ms/step - accuracy: 0.6803 - loss: 1.4607 - val_accuracy: 0.0761 - val_loss: 8.9416
# Epoch 49/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 32s 166ms/step - accuracy: 0.6870 - loss: 1.4361 - val_accuracy: 0.0774 - val_loss: 8.9911
# Epoch 50/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 158ms/step - accuracy: 0.6917 - loss: 1.4022 - val_accuracy: 0.0729 - val_loss: 9.0520
# Epoch 51/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 157ms/step - accuracy: 0.7096 - loss: 1.3359 - val_accuracy: 0.0735 - val_loss: 9.1208
# Epoch 52/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 157ms/step - accuracy: 0.7130 - loss: 1.3197 - val_accuracy: 0.0761 - val_loss: 9.1660
# Epoch 53/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 158ms/step - accuracy: 0.7237 - loss: 1.2829 - val_accuracy: 0.0738 - val_loss: 9.2412
# Epoch 54/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 156ms/step - accuracy: 0.7286 - loss: 1.2733 - val_accuracy: 0.0754 - val_loss: 9.3076
# Epoch 55/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 160ms/step - accuracy: 0.7389 - loss: 1.2189 - val_accuracy: 0.0726 - val_loss: 9.3533
# Epoch 56/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 158ms/step - accuracy: 0.7380 - loss: 1.1907 - val_accuracy: 0.0751 - val_loss: 9.4378
# Epoch 57/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 156ms/step - accuracy: 0.7636 - loss: 1.1139 - val_accuracy: 0.0735 - val_loss: 9.4947
# Epoch 58/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 155ms/step - accuracy: 0.7578 - loss: 1.1065 - val_accuracy: 0.0764 - val_loss: 9.5582
# Epoch 59/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 155ms/step - accuracy: 0.7618 - loss: 1.0893 - val_accuracy: 0.0764 - val_loss: 9.6247
# Epoch 60/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 156ms/step - accuracy: 0.7695 - loss: 1.0672 - val_accuracy: 0.0713 - val_loss: 9.7074
# Epoch 61/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 156ms/step - accuracy: 0.7804 - loss: 1.0301 - val_accuracy: 0.0726 - val_loss: 9.7441
# Epoch 62/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 156ms/step - accuracy: 0.7801 - loss: 1.0212 - val_accuracy: 0.0751 - val_loss: 9.7972
# Epoch 63/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 32s 163ms/step - accuracy: 0.7953 - loss: 0.9690 - val_accuracy: 0.0751 - val_loss: 9.8644
# Epoch 64/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 32s 162ms/step - accuracy: 0.7961 - loss: 0.9483 - val_accuracy: 0.0748 - val_loss: 9.9228
# Epoch 65/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 158ms/step - accuracy: 0.8008 - loss: 0.9312 - val_accuracy: 0.0767 - val_loss: 9.9937
# Epoch 66/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 156ms/step - accuracy: 0.8092 - loss: 0.9097 - val_accuracy: 0.0780 - val_loss: 10.0428
# Epoch 67/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 157ms/step - accuracy: 0.8152 - loss: 0.8849 - val_accuracy: 0.0767 - val_loss: 10.1043
# Epoch 68/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 156ms/step - accuracy: 0.8192 - loss: 0.8398 - val_accuracy: 0.0758 - val_loss: 10.1682
# Epoch 69/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 158ms/step - accuracy: 0.8251 - loss: 0.8371 - val_accuracy: 0.0742 - val_loss: 10.2160
# Epoch 70/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 157ms/step - accuracy: 0.8280 - loss: 0.8214 - val_accuracy: 0.0783 - val_loss: 10.2819
# Epoch 71/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 157ms/step - accuracy: 0.8305 - loss: 0.7845 - val_accuracy: 0.0758 - val_loss: 10.3347
# Epoch 72/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 156ms/step - accuracy: 0.8365 - loss: 0.7680 - val_accuracy: 0.0729 - val_loss: 10.3942
# Epoch 73/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 159ms/step - accuracy: 0.8462 - loss: 0.7335 - val_accuracy: 0.0754 - val_loss: 10.4370
# Epoch 74/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 156ms/step - accuracy: 0.8447 - loss: 0.7314 - val_accuracy: 0.0726 - val_loss: 10.4987
# Epoch 75/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 158ms/step - accuracy: 0.8503 - loss: 0.7114 - val_accuracy: 0.0742 - val_loss: 10.5682
# Epoch 76/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 37s 137ms/step - accuracy: 0.8552 - loss: 0.6853 - val_accuracy: 0.0754 - val_loss: 10.6442
# Epoch 77/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 160ms/step - accuracy: 0.8500 - loss: 0.6918 - val_accuracy: 0.0754 - val_loss: 10.6617
# Epoch 78/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 157ms/step - accuracy: 0.8595 - loss: 0.6657 - val_accuracy: 0.0745 - val_loss: 10.7241
# Epoch 79/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 32s 162ms/step - accuracy: 0.8639 - loss: 0.6575 - val_accuracy: 0.0729 - val_loss: 10.7769
# Epoch 80/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 156ms/step - accuracy: 0.8646 - loss: 0.6421 - val_accuracy: 0.0709 - val_loss: 10.8308
# Epoch 81/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 154ms/step - accuracy: 0.8606 - loss: 0.6373 - val_accuracy: 0.0758 - val_loss: 10.8941
# Epoch 82/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 154ms/step - accuracy: 0.8651 - loss: 0.6153 - val_accuracy: 0.0703 - val_loss: 10.9543
# Epoch 83/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 155ms/step - accuracy: 0.8676 - loss: 0.5971 - val_accuracy: 0.0719 - val_loss: 11.0189
# Epoch 84/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 155ms/step - accuracy: 0.8722 - loss: 0.5878 - val_accuracy: 0.0700 - val_loss: 11.0630
# Epoch 85/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 155ms/step - accuracy: 0.8768 - loss: 0.5643 - val_accuracy: 0.0742 - val_loss: 11.1048
# Epoch 86/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 153ms/step - accuracy: 0.8780 - loss: 0.5649 - val_accuracy: 0.0719 - val_loss: 11.1546
# Epoch 87/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 161ms/step - accuracy: 0.8733 - loss: 0.5584 - val_accuracy: 0.0703 - val_loss: 11.2146
# Epoch 88/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 155ms/step - accuracy: 0.8864 - loss: 0.5237 - val_accuracy: 0.0709 - val_loss: 11.2673
# Epoch 89/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 155ms/step - accuracy: 0.8832 - loss: 0.5357 - val_accuracy: 0.0690 - val_loss: 11.3191
# Epoch 90/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 42s 217ms/step - accuracy: 0.8840 - loss: 0.5164 - val_accuracy: 0.0722 - val_loss: 11.3908
# Epoch 91/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 32s 164ms/step - accuracy: 0.8836 - loss: 0.5146 - val_accuracy: 0.0726 - val_loss: 11.4346
# Epoch 92/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 157ms/step - accuracy: 0.8863 - loss: 0.5080 - val_accuracy: 0.0719 - val_loss: 11.4942
# Epoch 93/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 154ms/step - accuracy: 0.8951 - loss: 0.4717 - val_accuracy: 0.0716 - val_loss: 11.5162
# Epoch 94/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 155ms/step - accuracy: 0.8919 - loss: 0.4767 - val_accuracy: 0.0703 - val_loss: 11.5881
# Epoch 95/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 154ms/step - accuracy: 0.8934 - loss: 0.4688 - val_accuracy: 0.0742 - val_loss: 11.6035
# Epoch 96/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 154ms/step - accuracy: 0.8968 - loss: 0.4550 - val_accuracy: 0.0719 - val_loss: 11.6753
# Epoch 97/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 155ms/step - accuracy: 0.8939 - loss: 0.4477 - val_accuracy: 0.0706 - val_loss: 11.7322
# Epoch 98/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 154ms/step - accuracy: 0.8952 - loss: 0.4479 - val_accuracy: 0.0703 - val_loss: 11.7834
# Epoch 99/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 31s 160ms/step - accuracy: 0.9002 - loss: 0.4323 - val_accuracy: 0.0722 - val_loss: 11.8308
# Epoch 100/100
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 30s 154ms/step - accuracy: 0.8943 - loss: 0.4397 - val_accuracy: 0.0690 - val_loss: 11.8716

# %%
model = load_model("model.keras")
with open('/tokenizer.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
max_sequence_len=115
seed_text = "Dans le palais de Thèbes, on pouvait entendre"
# predict word number
next_words = 15

for _ in range(next_words):
    #convert to token
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    #path sequences
    token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
    predicted = np.argmax(model.predict(token_list), axis=-1)
    output_word = ""
    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break
    seed_text += " " + output_word
